# %%
import csv
import re
import pandas as pd

# %%
with open('houses.csv', 'r') as file:
    reader = csv.DictReader(file)
    rows = list(reader)

# %%
# land size 0-0-0-0 to sqft
def convert_to_square_feet(value):
    parts = value.split(',')
    square_feet = 0.0
    for part in parts:
        sub_parts = part.split('-')
        
        if len(sub_parts) == 4:
            try:
                aana = float(sub_parts[1])
                ropani = float(sub_parts[0])
                dam = float(sub_parts[3])
                paisa = float(sub_parts[2])

                square_feet += (aana * 342.25) + (ropani * 5476) + (dam * 21.39) + (paisa * 85.56)
                break
            except ValueError:
                pass
    return square_feet

csv_file = 'houses2.csv'

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    rows = list(reader)

for row in rows:
    landsize = row['Land']
    converted = convert_to_square_feet(landsize)  
   
    if converted ==0:
        row['Land'] = landsize
    else:
        row['Land'] = str(converted)

with open('hamrobaar_SM2.csv', 'w', newline='') as file:
    fieldnames = reader.fieldnames
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 23
#      19     return square_feet
#      21 csv_file = 'houses2.csv'
# ---> 23 with open(csv_file, 'r') as file:
#      24     reader = csv.DictReader(file)
#      25     rows = list(reader)
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'houses2.csv'

# %%
#district choose ktm lmc bkt
csv_file = 'new2w.csv'
updated_csv_file = 'updated_houses.csv'
districts_to_keep = ['kathmandu', 'lalitpur', 'bhaktapur']

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        district = row['district'].lower()
        if district in districts_to_keep:
            updated_rows.append(row)

fieldnames = reader.fieldnames

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
#district sort acc to district
csv_file = 'new2w.csv'
updated_csv_file = 'updated_houses.csv'
districts_to_keep = ['kathmandu', 'lalitpur', 'bhaktapur']

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        district = row['district'].lower()
        if district in districts_to_keep:
            updated_rows.append(row)

sorted_rows = sorted(updated_rows, key=lambda x: districts_to_keep.index(x['district'].lower()))

fieldnames = reader.fieldnames

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(sorted_rows)

# %%
#remove , from price
csv_file = 'houses.csv'
updated_csv_file = 'updated_houses4.csv'

def remove_comma(value):
    return value.replace(',', '')

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    for row in reader:
        row['price'] = remove_comma(row['price'])
        updated_rows.append(row)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
#landsize aana to sqft
csv_file = 'updated_houses1.csv'
updated_csv_file = 'updated_houses2.csv'

def convert_to_square_feet(value):
    try:
        parts = value.split()
        if len(parts) == 2 and parts[1].upper() == 'AANA':
            aana = float(parts[0])
            return str(aana * 342.25)
    except (ValueError, IndexError):
        pass
    return value

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    for row in reader:
        row['Land'] = convert_to_square_feet(row['Land'])
        updated_rows.append(row)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
#convert landsize to 0-0-0-
csv_file = 'updated_houses.csv'
updated_csv_file = 'updated_houses1.csv'

def convert_to_ropani_aana_daam_paisa(value):
    try:
        parts = value.split()
        if any(keyword.upper() in parts for keyword in ['AANA', 'PAISA', 'DAM', 'ROPANI']):
            aana = 0
            ropani = 0
            dam = 0
            paisa = 0

            for part in parts:
                if part.upper() == 'AANA':
                    aana = int(parts[parts.index(part) - 1])
                elif part.upper() == 'PAISA':
                    paisa = int(parts[parts.index(part) - 1])
                elif part.upper() == 'DAM':
                    dam = int(parts[parts.index(part) - 1])
                elif part.upper() == 'ROPANI':
                    ropani = int(parts[parts.index(part) - 1])

            return f'{ropani}-{aana}-{dam}-{paisa}'

    except (ValueError, IndexError):
        pass
    return value

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    for row in reader:
        row['Land'] = convert_to_ropani_aana_daam_paisa(row['Land'])
        updated_rows.append(row)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
import csv

csv_file = 'updated_houses2.csv'
updated_csv_file = 'updated_houses3.csv'

def convert_to_square_feet(value):
    sub_parts = value.split('-')
    if len(sub_parts) == 4:
        try:
            ropani = float(sub_parts[0])
            aana = float(sub_parts[1])
            dam = float(sub_parts[2])
            paisa = float(sub_parts[3])

            square_feet = (ropani * 5476) + (aana * 342.25) + (dam * 21.39) + (paisa * 85.56)
            return square_feet
        except ValueError:
            pass
    return value

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    for row in reader:
        row['Land'] = str(convert_to_square_feet(row['Land']))
        updated_rows.append(row)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
csv_file = 'updated_houses9.csv'
updated_csv_file = 'updated_houses90.csv'

def update_landsize(value):
    try:
        square_feet = float(value)
        if square_feet < 10:
            square_feet *= 342.25
        return str(square_feet)
    except ValueError:
        return value

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    for row in reader:
        row['landsize'] = update_landsize(row['landsize'])
        updated_rows.append(row)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
#remove rented houses
csv_file = 'updated_houses91.csv'
updated_csv_file = 'updated_houses92.csv'

def remove_rent_rows(rows):
    updated_rows = []
    for row in rows:
        if 'rent' not in row['title'].lower():
            updated_rows.append(row)
    return updated_rows

rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    rows = list(reader)

updated_rows = remove_rent_rows(rows)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)

# %%
csv_file = 'updated_houses92.csv'
updated_csv_file = 'updated_houses93.csv'

def multiply_landsize(value):
    try:
        square_feet = float(value)
        if 10 <= square_feet <= 30:
            square_feet *= 85.56
        return str(square_feet)
    except ValueError:
        return value

updated_rows = []

with open(csv_file, 'r') as file:
    reader = csv.DictReader(file)
    fieldnames = reader.fieldnames
    for row in reader:
        row['landsize'] = multiply_landsize(row['landsize'])
        updated_rows.append(row)

with open(updated_csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(updated_rows)
