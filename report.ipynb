# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("latlong.csv")

# %%
print(data.head())
print(data.describe())
# Out:
#       Price      Address  Floor  Bathroom  Bedroom     Land  Road       City  \
# 0  31500000  Aakasedhara    2.5       5.0        6  1711.25  12.0  Kathmandu
# 1  16000000  Aakasedhara    2.5       2.0        6  1112.31  13.0  Kathmandu
# 2  38000000  Aakasedhara    2.5       2.0        4  2395.75  13.0  Kathmandu
# 3  21000000  Aakasedhara    3.0       4.0        9  1369.00  13.0  Kathmandu
# 4  25000000  Aakasedhara    3.0       4.0        6  1369.00  13.0  Kathmandu
#
#          Face
# 0  South West
# 1        West
# 2        West
# 3        West
# 4        West
#               Price        Floor     Bathroom      Bedroom         Land  \
# count  3.026000e+03  3026.000000  3026.000000  3026.000000  3026.000000
# mean   3.336922e+07     2.741639     3.791474     5.078652  1519.090328
# std    1.360999e+07     0.352668     1.031555     1.369235   555.484786
# min    1.000000e+07     2.000000     1.000000     1.000000    85.562500
# 25%    2.400000e+07     2.500000     3.000000     4.000000  1095.200000
# 50%    2.950000e+07     2.500000     4.000000     5.000000  1369.000000
# 75%    3.990000e+07     3.000000     4.000000     6.000000  1711.250000
# max    8.750000e+07     3.500000     8.000000     9.000000  3422.500000
#
#               Road
# count  3026.000000
# mean     13.814996
# std       2.431245
# min       9.000000
# 25%      13.000000
# 50%      13.000000
# 75%      13.000000
# max      20.500000

# %%
# Scatter plot: Land vs. Price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Land', y='Price')
plt.title('Land Area vs. House Price')
plt.xlabel('Land Area')
plt.ylabel('House Price')
plt.show()

# %%
# Histogram: Distribution of House Prices
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Price', bins=20)
plt.title('Distribution of House Prices')
plt.xlabel('House Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Statistical analysis
mean_price = data['Price'].mean()
median_price = data['Price'].median()
min_price = data['Price'].min()
max_price = data['Price'].max()

# %%
# Generate the report
report = f"""
Data Analysis Report:

- Number of data points: {len(data)}
- Land area summary:
    - Minimum land area: {data['Land'].min()}
    - Maximum land area: {data['Land'].max()}
- House price summary:
    - Minimum house price: {min_price}
    - Maximum house price: {max_price}
    - Average house price: {mean_price}
    - Median house price: {median_price}
"""

print(report)
# Out:
# Data Analysis Report:
#
# - Number of data points: 3026
# - Land area summary:
#     - Minimum land area: 85.5625
#     - Maximum land area: 3422.5
# - House price summary:
#     - Minimum house price: 10000000
#     - Maximum house price: 87500000
#     - Average house price: 33369219.51321877
#     - Median house price: 29500000.0
